# %% [markdown]
# # Usar API para Localizar endereços completos

# %%
#pacotes
import pandas as pd
import urllib.request
import json

# %%
#importação, transforma em str para a API ler
df_original = pd.read_excel("C:\Python\dados.xlsx", dtype={'CEP':'str'})

# %% [markdown]
# # Análise Exploratória

# %%
df_original.shape
# Out:
# (999, 1)

# %%
df_original.head
# Out:
# <bound method NDFrame.head of           CEP
# 0    69043690
# 1    08130230
# 2    01404000
# 3    22221971
# 4    49230000
# ..        ...
# 994  21920240
# 995  08615070
# 996  88080760
# 997  01323050
# 998  04011060
#
# [999 rows x 1 columns]>

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CEP     999 non-null    object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
#remover duplicados
df_ceps_clientes = df_original['CEP']
df_ceps_clientes = pd.DataFrame(df_ceps_clientes)
df_ceps_clientes.drop_duplicates(inplace = True)
df_ceps_clientes.head()
# Out:
#         CEP
# 0  69043690
# 1  08130230
# 2  01404000
# 3  22221971
# 4  49230000

# %%
#qtde ceps únicos
print("Ceps únicos de clientes:", df_ceps_clientes.count())
# Out:
# Ceps únicos de clientes: CEP    971
# dtype: int64

# %%
#consultar API, abaixo caminho, com um cep de exemplo 74491628 pra testar se funciona
url = 'https://viacep.com.br/ws/%s/json' % '74491628'
headers = {'User-Agent': 'Autociencia/1.0'}
#faz a chamada da API
requisicao = urllib.request.Request(url, headers=headers, method='GET')
cliente = urllib.request.urlopen(requisicao)
conteudo = cliente.read().decode('utf-8')
endereco = json.loads(conteudo)

# %%
#endereco completo, mas sem o tratamento dos dados
print(endereco)
# Out:
# {'cep': '74491-628', 'logradouro': 'Rua JC311', 'complemento': '', 'unidade': '', 'bairro': 'Residencial Jardins do Cerrado 7', 'localidade': 'Goiânia', 'uf': 'GO', 'ibge': '5208707', 'gia': '', 'ddd': '62', 'siafi': '9373'}

# %%
#separando os valores do dicionário
print('Endereco: ',endereco['logradouro'])
print('Bairro: ',endereco['bairro'])
print('Cidade: ',endereco['localidade'])
print('Estado: ',endereco['uf'])
# Out:
# Endereco:  Rua JC311
# Bairro:  Residencial Jardins do Cerrado 7
# Cidade:  Goiânia
# Estado:  GO

# %% [markdown]
# # Todos os endereços

# %%
#iteraçao linha por linha no df
for idx, row in df_ceps_clientes.iterrows():
    #var cep pega a col cep
    cep = row.CEP
    url = 'https://viacep.com.br/ws/%s/json' % cep #coloca a var novamente
    headers = {'User-Agent': 'Autociencia/1.0'}
    #faz a chamada da API
    requisicao = urllib.request.Request(url, headers=headers, method='GET')
    cliente = urllib.request.urlopen(requisicao)
    conteudo = cliente.read().decode('utf-8')
    endereco = json.loads(conteudo)
    cliente.close() #deve fechar a chamada pq senao dá erro
    print(cep)
    #cria as colunas e popula com as informações
    if "cep" in endereco:
        df_ceps_clientes.at[idx, 'Endereco_cliente'] = endereco['logradouro']
        df_ceps_clientes.at[idx, 'Bairro_cliente'] = endereco['bairro']
        df_ceps_clientes.at[idx, 'Cidade_cliente'] = endereco['localidade']
        df_ceps_clientes.at[idx, 'Estado_cliente'] = endereco['uf']
        
    else:
        df_ceps_clientes.at[idx, 'Endereco_cliente'] = 'Não Localizado'
        df_ceps_clientes.at[idx, 'Bairro_cliente'] = 'Não Localizado'
# 04037001
# 71929180
# 45810000
# 05302051
# 78043268
# 31525000
# 04515011
# 05872030
# 05438100
# 26383140
# 04010100
# 22775046
# 90050003
# 52060140
# 07124030
# 22230060
# 21051470
# 20560095
# 20261066
# 74223210
# 20510060
# 30882620
# 86050520
# 22230000
# 30320250
# 93125320
# 22245000
# 52040020
# 20270245
# 04037000
# 04785120
# 22250080
# 72705010
# 05437002
# 04376008
# 02336100
# 05445030
# 20735180
# 70130300
# 53140080
# 22051020
# 30130003
# 52070008
# 57042560
# 04432120
# 01415000
# 61936030
# 71070237
# 39820000
# 13270230
# 92480000
# 09070090
# 01105040
# 95500000
# 81610060
# 23056050
# 22740300
# 88040440
# 06233030
# 59067530
# 14022310
# 58038230
# 72220051
# 06539105
# 30150370
# 70390050
# 07940140
# 57037530
# 01420000
# 01329010
# 03977520
# 25035250
# 31330628
# 22030002
# 88080250
# 22245080
# 03087080
# 21070360
# 01240001
# 31810000
# 89012160
# 30520420
# 04125040
# 90630180
# 22460050
# 54440290
# 20720350
# 38401434
# 37701097
# 20240180
# 29102568
# 22031071
# 02258010
# 06083215
# 01229001
# 13085220
# 05432010
# 21221490
# 22231140
# 24342010
# 21321620
# 01154001
# 22410002
# 62365000
# 13140000
# 60055171
# 32667460
# 49095780
# 05016000
# 34004166
# 20530001
# 20531420
# 24220301
# 13030580
# 22430210
# 22770080
# 22461240
# 20710290
# 13201070
# 12900480
# 18150000
# 22260210
# 22270001
# 25850000
# 90540000
# 30830093
# 72315105
# 88030300
# 20961060
# 12228460
# 78050192
# 05584030
# 62250000
# 22411001
# 22753737
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\AppData\Local\anaconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\anaconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\anaconda3\Lib\http\client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\anaconda3\Lib\http\client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File ~\AppData\Local\anaconda3\Lib\http\client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File ~\AppData\Local\anaconda3\Lib\http\client.py:1458, in HTTPSConnection.connect(self)
#    1456     server_hostname = self.host
# -> 1458 self.sock = self._context.wrap_socket(self.sock,
#    1459                                       server_hostname=server_hostname)
#
# File ~\AppData\Local\anaconda3\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~\AppData\Local\anaconda3\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File ~\AppData\Local\anaconda3\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# TimeoutError: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[12], line 9
#       7 #faz a chamada da API
#       8 requisicao = urllib.request.Request(url, headers=headers, method='GET')
# ----> 9 cliente = urllib.request.urlopen(requisicao)
#      10 conteudo = cliente.read().decode('utf-8')
#      11 endereco = json.loads(conteudo)
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu>

# %%
df_ceps_clientes.head(30)
# Out:
#          CEP                        Endereco_cliente  \
# 0   69043690                      Rua Violeta Areosa
# 1   08130230                 Rua Marco Antônio Setti
# 2   01404000                        Alameda Campinas
# 3   22221971                        Largo do Machado
# 4   49230000
# 5   38057050                        Alameda Vermelha
# 6   21321310                             Rua Urucuia
# 7   72153522               Setor SIG Área Especial 2
# 8   02736070                        Rua Miguel Helou
# 9   30220400                            Rua Capivari
# 10  24020040                            Rua São João
# 11  08715460                          Travessa Elgin
# 12  39801022                    Rua José Luiz Tanure
# 13  24130465        Travessa Manoel da Encarnação Sá
# 14  45028190                     Rua Cláudia Botelho
# 15  11030320                         Rua Tiago Tacão
# 16  06407000  Estrada Doutor Cícero Borges de Morais
# 17  90620000                 Avenida Princesa Isabel
# 18  31741550                      Rua Aderito Távora
# 19  14890038                       Rua Manoel Afonso
# 20  22240004                     Rua das Laranjeiras
# 21  77760000
# 22  60170041                       Rua Leonardo Mota
# 23  31730690               Rua Herculano Dias Coelho
# 24  38406586               Alameda Angico do Cerrado
# 25  04104001                        Rua Correia Dias
# 26  36088120            Rua Antônio Joaquim da Silva
# 27  02801000           Avenida Elísio Teixeira Leite
# 28  04930300          Rua Jornalista Marçal Versiani
# 29  04131130                Rua Doutor Malta Cardoso
#
#                    Bairro_cliente         Cidade_cliente Estado_cliente
# 0                        Alvorada                 Manaus             AM
# 1                    Cidade Kemel              São Paulo             SP
# 2                 Jardim Paulista              São Paulo             SP
# 3                          Catete         Rio de Janeiro             RJ
# 4                                  Santa Luzia do Itanhy             SE
# 5                Grande Horizonte                Uberaba             MG
# 6                  Vila Valqueire         Rio de Janeiro             RJ
# 7   Taguatinga Norte (Taguatinga)               Brasília             DF
# 8          Parque Monteiro Soares              São Paulo             SP
# 9                           Serra         Belo Horizonte             MG
# 10                         Centro                Niterói             RJ
# 11                         Centro        Mogi das Cruzes             SP
# 12                       Ipiranga          Teófilo Otoni             MG
# 13                        Fonseca                Niterói             RJ
# 14                       Candeias   Vitória da Conquista             BA
# 15                 Ponta da Praia                 Santos             SP
# 16                 Vila Universal                Barueri             SP
# 17                        Santana           Porto Alegre             RS
# 18                     Heliópolis         Belo Horizonte             MG
# 19                 Jardim Tangará            Jaboticabal             SP
# 20                    Laranjeiras         Rio de Janeiro             RJ
# 21                                  Colinas do Tocantins             TO
# 22                        Aldeota              Fortaleza             CE
# 23                       Planalto         Belo Horizonte             MG
# 24             Bosque dos Buritis             Uberlândia             MG
# 25                        Paraíso              São Paulo             SP
# 26                     Santa Cruz           Juiz de Fora             MG
# 27               Vila Brasilândia              São Paulo             SP
# 28         Jardim Santa Margarida              São Paulo             SP
# 29                Vila Gumercindo              São Paulo             SP

# %%
df_ceps_clientes.to_csv('ceps_clientes.csv', index=False)

# %% [markdown]
# # Fim
